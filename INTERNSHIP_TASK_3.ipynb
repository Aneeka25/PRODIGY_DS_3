# %% [markdown]
# <a href="https://colab.research.google.com/github/Aneeka25/PRODIGY_DS_3/blob/main/INTERNSHIP_TASK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#importing the path of the data
url="https://github.com/m4gaikwad/PandasTutorial/raw/main/online_store_customer_data.csv"

# %%
data = pd.read_csv(url,on_bad_lines='skip')
data
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
data.rename(columns={"Transactiond_Date" : 'Date',
'State_name ': 'State'},inplace =True)

# %%
data.sample(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 1289        2/25/2020          152477    Male  40.0         Single
# 82          1/31/2019          151277  Female  70.0        Married
# 17           1/7/2019          151217  Female  77.0        Married
# 303         4/14/2019          151491    Male  48.0        Married
# 1247        2/12/2020          152435    Male  43.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 1289     Georgia    Silver        Employees         PayPal      1.0
# 82          Ohio    Silver          workers          Other      1.0
# 17    New Mexico  Platinum          workers           Card      0.0
# 303   California  Platinum          workers         PayPal      1.0
# 1247    Arkansas    Silver          workers           Card      1.0
#
#       Amount_spent
# 1289        966.13
# 82          574.10
# 17         2999.98
# 303         910.97
# 1247           NaN

# %%
data[data['State_names']== 'Kansas' ]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 60          1/26/2019          151260    Male  55.0        Married
# 65          1/26/2019          151260    Male  55.0        Married
# 100          2/6/2019          151295  Female  22.0        Married
# 126         2/12/2019          151314  Female  55.0        Married
# 139         2/17/2019          151327  Female  77.0         Single
# 336         4/22/2019          151524    Male  70.0        Married
# 368          5/3/2019          151556    Male  70.0         Single
# 468          6/3/2019          151656  Female  49.0         Single
# 521         6/20/2019          151709  Female  76.0         Single
# 558         6/30/2019          151746    Male  48.0        Married
# 569          7/4/2019          151757  Female  20.0         Single
# 572          7/5/2019          151760  Female  61.0        Married
# ...

# %%
data[(data['Age'] >= 45) & (data['Age']<= 60)]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 1            1/1/2019          151201    Male  49.0         Single
# 10           1/4/2019          151210  Female  56.0        Married
# 12           1/5/2019          151212  Female  60.0        Married
# 13           1/5/2019          151213    Male  47.0         Single
# 19           1/8/2019          151219  Female  46.0        Married
# ...               ...             ...     ...   ...            ...
# 2494        4/27/2021          153682    Male  56.0        Married
# 2498        4/28/2021          153686  Female  55.0         Single
# 2505        4/30/2021          153693    Male  54.0        Married
# 2507         5/1/2021          153695  Female  57.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 1           Illinois     Basic    self-employed           Card      0.0
# ...

# %%
data[(data['Age'] >= 45) & (data['Age']<= 60) & (data['Marital_status'] == "Single" )& (data["Gender"] == 'Male')]
# Out:
#      Transaction_date  Transaction_ID Gender   Age Marital_status  \
# 1            1/1/2019          151201   Male  49.0         Single
# 13           1/5/2019          151213   Male  47.0         Single
# 23           1/9/2019          151223   Male  47.0         Single
# 51          1/22/2019          151251   Male  56.0         Single
# 53          1/23/2019          151253   Male  51.0         Single
# ...               ...             ...    ...   ...            ...
# 2392        3/23/2021          153580   Male  46.0         Single
# 2427         4/5/2021          153615   Male  49.0         Single
# 2433         4/6/2021          153621   Male  53.0         Single
# 2453        4/13/2021          153641   Male  52.0         Single
# 2511         5/1/2021          153699   Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 1           Illinois     Basic    self-employed           Card      0.0
# ...

# %%
df = data.dropna(subset = ['Age'])

# %%
df['Age_Range'] = np.where(df['Age'] <= 30,'Young',
np.where(df['Age']<= 45,'Middle',
'old'))
df['Age_Range']
# Out:
# <ipython-input-14-3f2c00c70d89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_Range'] = np.where(df['Age'] <= 30,'Young',
# 0        Young
# 1          old
# 2          old
# 3        Young
# 4        Young
#          ...
# 2507       old
# 2508    Middle
# 2509     Young
# 2510    Middle
# 2511       old
# Name: Age_Range, Length: 2470, dtype: object

# %%
df.head(5)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent Age_Range
# 0     Basic     Unemployment          Other      1.0       2051.36     Young
# 1     Basic    self-employed           Card      0.0        544.04       old
# 2     Basic          workers         PayPal      1.0       1572.60       old
# 3  Platinum          workers           Card      1.0       1199.79     Young
# 4     Basic    self-employed           Card      0.0           NaN     Young

# %%
df.groupby('Age_Range')['Age'].count()
# Out:
# Age_Range
# Middle     601
# Young      580
# old       1289
# Name: Age, dtype: int64

# %%
df.sort_values(by = "Amount_spent",ascending=False)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17           1/7/2019          151217  Female  77.0        Married
# 485          6/7/2019          151673    Male  65.0        Married
# 2279        2/15/2021          153467  Female  78.0         Single
# 589         7/13/2019          151777    Male  51.0         Single
# 743         8/30/2019          151931    Male  44.0         Single
# ...               ...             ...     ...   ...            ...
# 2482        4/23/2021          153670  Female  77.0        Married
# 2484        4/24/2021          153672    Male  65.0         Single
# 2495        4/27/2021          153683  Female  20.0        Married
# 2496        4/28/2021          153684  Female  33.0        Married
# 2501        4/29/2021          153689  Female  65.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# ...

# %%
df.nlargest(5,'Amount_spent')
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17           1/7/2019          151217  Female  77.0        Married
# 485          6/7/2019          151673    Male  65.0        Married
# 2279        2/15/2021          153467  Female  78.0         Single
# 589         7/13/2019          151777    Male  51.0         Single
# 743         8/30/2019          151931    Male  44.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# 485          Arizona      Gold    self-employed         PayPal      1.0
# 2279         Arizona    Silver        Employees         PayPal      1.0
# 589   North Carolina   Missing        Employees         PayPal      1.0
# 743         Illinois     Basic        Employees           Card      1.0
#
#       Amount_spent Age_Range
# 17         2999.98       old
# 485        2998.62       old
# 2279       2997.21       old
# ...

# %%
df[['Age_Range','Amount_spent']].groupby(df['Age_Range']).mean()
# Out:
# <ipython-input-20-91f8148effeb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Age_Range','Amount_spent']].groupby(df['Age_Range']).mean()
#            Amount_spent
# Age_Range
# Middle      1392.696599
# Young       1469.033012
# old         1416.710717

# %%
pd.crosstab(df['Age_Range'],df['Payment_method'])
# Out:
# Payment_method  Card  Other  PayPal
# Age_Range
# Middle           196    135     270
# Young            173    133     274
# old              365    320     604

# %%
pd.crosstab(df['Age_Range'],df['Payment_method']).plot(kind='bar')
# Out:
# <Axes: xlabel='Age_Range'>

# %%
df.plot('Age_Range','Amount_spent')
# Out:
# <Axes: xlabel='Age_Range'>

# %%
df.Age_Range.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Age_Range'>
